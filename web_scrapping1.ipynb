# %% [markdown]
# <a href="https://colab.research.google.com/github/KAsHiSHSET/PRAC_SESSION/blob/main/web_scrapping1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
# headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
url='https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_1_books?ie=UTF8&pg=1'
webpage=requests.get(url).text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:end-feature:cs-optimization -->
#   <!-- sp:feature:csm:head-open-part2 -->
#   <!-- sp:end-feature:csm:head-open-part2 -->
#   <!-- sp:feature:aui-assets -->
# ...

# %%
#h1 tag printed
soup.find_all('h1')[0].text
# Out:
# 'Bestsellers in Books'

# %%
#div tag printed
for i in soup.find_all('div'):
  print(i.text.strip())
# Out:
# Skip to main content
#
#
#
#
#
#
#
#
#
#
# .in
#
#
#
#
#
#
#
#
#
#                    Delivering to Mumbai 400001
#
#
#                    Update location
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Books
#
#
# Select the department you want to search in
#
# All Categories
# Alexa Skills
# Amazon Devices
# Amazon Fashion
# Amazon Fresh
# Amazon Fresh Meat
# Amazon Pharmacy
# Appliances
# Apps & Games
# Audible Audiobooks
# Baby
# Beauty
# Books
# Car & Motorbike
# Clothing & Accessories
# Collectibles
# Computers & Accessories
# Deals
# Electronics
# Furniture
# Garden & Outdoors
# Gift Cards
# Grocery & Gourmet Foods
# Health & Personal Care
# Home & Kitchen
# Industrial & Scientific
# Jewellery
# Kindle Store
# Luggage & Bags
# Luxury Beauty
# Movies & TV Shows
# MP3 Music
# Music
# Musical Instruments
# Office Products
# Pet Supplies
# Prime Video
# Shoes & Handbags
# Software
# Sports, Fitness & Outdoors
# Subscribe & Save
# Tools & Home Improvement
# Toys & Games
# Under ₹500
# ...

# %%
for i in soup.find_all('span'):
  print(i.text.strip())
# Out:
# .in
# Delivering to Mumbai 400001
#
#
#                    Update location
# Delivering to Mumbai 400001
# Update location
# Books
#
# EN
#
# EN
#
#
# Hello, sign in
# Account & Lists
#
# Returns
# & Orders
#
#
#
#
# Cart
#
# All
# Fresh
#
# Prime
#
# Books
# Advanced Search
# New Releases & Pre-orders
# Best Sellers
#
# Browse Genres
#
# Children's & Young Adult
#
# Textbooks
#
# Exam Central
#
# All Indian Languages
#
# Amazon Bestsellers
# Our most popular products based on sales.  Updated frequently.
# #51
# Days at the Morisaki Bookshop : A charming and uplifting Japanese translated story on the healing power of books
# 4.4 out of 5 stars
# 4,408
# Paperback
# 24 offers from ₹275.00
# ₹275.00
# ₹275.00
# #52
# Story Books for Kids - Second Reader (Illustrated) (Set of 6 Books) - Phonic stories - Bedtime Stories - 3 Years to 6 Years Old - Read Aloud to Infants, Toddlers
# 4.3 out of 5 stars
# 264
# Paperback
# 3 offers from ₹153.00
# ₹153.00
# ₹153.00
# #53
# ...

# %%
for i in soup.find_all('div'):
  print(i.text.strip())
# Out:
# Skip to main content
#
#
#
#
#
#
#
#
#
#
# .in
#
#
#
#
#
#
#
#
#
#                    Delivering to Mumbai 400001
#
#
#                    Update location
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Books
#
#
# Select the department you want to search in
#
# All Categories
# Alexa Skills
# Amazon Devices
# Amazon Fashion
# Amazon Fresh
# Amazon Fresh Meat
# Amazon Pharmacy
# Appliances
# Apps & Games
# Audible Audiobooks
# Baby
# Beauty
# Books
# Car & Motorbike
# Clothing & Accessories
# Collectibles
# Computers & Accessories
# Deals
# Electronics
# Furniture
# Garden & Outdoors
# Gift Cards
# Grocery & Gourmet Foods
# Health & Personal Care
# Home & Kitchen
# Industrial & Scientific
# Jewellery
# Kindle Store
# Luggage & Bags
# Luxury Beauty
# Movies & TV Shows
# MP3 Music
# Music
# Musical Instruments
# Office Products
# Pet Supplies
# Prime Video
# Shoes & Handbags
# Software
# Sports, Fitness & Outdoors
# Subscribe & Save
# Tools & Home Improvement
# Toys & Games
# Under ₹500
# ...

# %%
len(soup.find_all('div',class_='_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y'))
# Out:
# 100

# %%
print(soup.find_all('div',class_='_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y'))
# Out:
# [<div class="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y">Days at the Morisaki Bookshop : A charming and uplifting Japanese translated story on the healing power of books</div>, <div class="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y">Satoshi Yagisawa</div>, <div class="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y">Story Books for Kids - Second Reader (Illustrated) (Set of 6 Books) - Phonic stories - Bedtime Stories - 3 Years to 6 Years Old - Read Aloud to Infants, Toddlers</div>, <div class="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y">Maple Press</div>, <div class="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y">NTA UGC NET '24 Paper 1 By Kvs Madaan|Teaching And Research Aptitude Net/Set/Jrf|Includes 2023 paper (2 Sets) &amp; 23 years chapter wise solved previous year questions|Includes 2600+ questions</div>, <div class="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y">KVS Madaan</div>, <div class="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y">Oxford Student Atlas for India | 5th Edition | For UPSC and Competitive Exams | Latest Ed
# ...

# %%
company=soup.find_all('div',class_='_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y')
company
# Out:
# [<div class="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y">Days at the Morisaki Bookshop : A charming and uplifting Japanese translated story on the healing power of books</div>,
#  <div class="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y">Satoshi Yagisawa</div>,
#  <div class="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y">Story Books for Kids - Second Reader (Illustrated) (Set of 6 Books) - Phonic stories - Bedtime Stories - 3 Years to 6 Years Old - Read Aloud to Infants, Toddlers</div>,
#  <div class="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y">Maple Press</div>,
#  <div class="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y">NTA UGC NET '24 Paper 1 By Kvs Madaan|Teaching And Research Aptitude Net/Set/Jrf|Includes 2023 paper (2 Sets) &amp; 23 years chapter wise solved previous year questions|Includes 2600+ questions</div>,
#  <div class="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y">KVS Madaan</div>,
# ...

# %%
company=soup.find_all('div',class_='company-content-wrapper')
company
# Out:
# []

# %%
for i in soup.find_all('a'):
  print(i.text.strip())
# Out:
# Skip to main content
# .in
# Delivering to Mumbai 400001
#
#
#                    Update location
# EN
# Hello, sign in
# Account & Lists
# Returns
# & Orders
# Cart
# All
# Fresh
# Amazon miniTV
# Sell
# Best Sellers
# Today's Deals
# Mobiles
# Customer Service
# Prime
# Electronics
# Fashion
# New Releases
# Home & Kitchen
# Amazon Pay
# Computers
# Gift Ideas
# Car & Motorbike
# Books
# Beauty & Personal Care
# Pet Supplies
# Grocery & Gourmet Foods
# Home Improvement
# Toys & Games
# Sports, Fitness & Outdoors
# Gift Cards
# Baby
# Custom Products
# Health, Household & Personal Care
# Video Games
# Audible
# AmazonBasics
# Subscribe & Save
# Coupons
# Books
# Advanced Search
# New Releases & Pre-orders
# Best Sellers
# Browse Genres
# Children's & Young Adult
# Textbooks
# Exam Central
# All Indian Languages
#
#
# Days at the Morisaki Bookshop : A charming and uplifting Japanese translated story on the healing power of books
# Satoshi Yagisawa
# 4.4 out of 5 stars 4,408
# ...

# %%
soup.find_all('h1').text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4e75c70fbfda> in <cell line: 1>()
# ----> 1 soup.find_all('h1').text
#
# NameError: name 'soup' is not defined

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
webpage=requests.get('https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_1_books?ie=UTF8&pg=1').text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:end-feature:cs-optimization -->
#   <!-- sp:feature:csm:head-open-part2 -->
#   <!-- sp:end-feature:csm:head-open-part2 -->
#   <!-- sp:feature:aui-assets -->
# ...

# %%
soup.find_all('h1').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-4e75c70fbfda> in <cell line: 1>()
# ----> 1 soup.find_all('h1').text
#
# /usr/local/lib/python3.10/dist-packages/bs4/element.py in __getattr__(self, key)
#    2431     def __getattr__(self, key):
#    2432         """Raise a helpful exception to explain a common code fix."""
# -> 2433         raise AttributeError(
#    2434             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
soup.find_all('h1')[1].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-99244af7e3cf> in <cell line: 1>()
# ----> 1 soup.find_all('h1')[1].text
#
# IndexError: list index out of range

# %%
soup.find_all('h1')[0].text
# Out:
# 'Bestsellers in Books'

# %%
for i in soup.find_all('div'):
  print(i.text.strip())
# Out:
# Skip to main content
#
#
#
#
#
#
#
#
#
#
# .in
#
#
#
#
#
#
#
#
#
#                    Delivering to Mumbai 400001
#
#
#                    Update location
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Books
#
#
# Select the department you want to search in
#
# All Categories
# Alexa Skills
# Amazon Devices
# Amazon Fashion
# Amazon Fresh
# Amazon Fresh Meat
# Amazon Pharmacy
# Appliances
# Apps & Games
# Audible Audiobooks
# Baby
# Beauty
# Books
# Car & Motorbike
# Clothing & Accessories
# Collectibles
# Computers & Accessories
# Deals
# Electronics
# Furniture
# Garden & Outdoors
# Gift Cards
# Grocery & Gourmet Foods
# Health & Personal Care
# Home & Kitchen
# Industrial & Scientific
# Jewellery
# Kindle Store
# Luggage & Bags
# Luxury Beauty
# Movies & TV Shows
# MP3 Music
# Music
# Musical Instruments
# Office Products
# Pet Supplies
# Prime Video
# Shoes & Handbags
# Software
# Sports, Fitness & Outdoors
# Subscribe & Save
# Tools & Home Improvement
# Toys & Games
# Under ₹500
# ...

# %%
for i in soup.find_all('div'):
  print(i.text.strip())
# Out:
# Skip to main content
#
#
#
#
#
#
#
#
#
#
# .in
#
#
#
#
#
#
#
#
#
#                    Delivering to Mumbai 400001
#
#
#                    Update location
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Books
#
#
# Select the department you want to search in
#
# All Categories
# Alexa Skills
# Amazon Devices
# Amazon Fashion
# Amazon Fresh
# Amazon Fresh Meat
# Amazon Pharmacy
# Appliances
# Apps & Games
# Audible Audiobooks
# Baby
# Beauty
# Books
# Car & Motorbike
# Clothing & Accessories
# Collectibles
# Computers & Accessories
# Deals
# Electronics
# Furniture
# Garden & Outdoors
# Gift Cards
# Grocery & Gourmet Foods
# Health & Personal Care
# Home & Kitchen
# Industrial & Scientific
# Jewellery
# Kindle Store
# Luggage & Bags
# Luxury Beauty
# Movies & TV Shows
# MP3 Music
# Music
# Musical Instruments
# Office Products
# Pet Supplies
# Prime Video
# Shoes & Handbags
# Software
# Sports, Fitness & Outdoors
# Subscribe & Save
# Tools & Home Improvement
# Toys & Games
# Under ₹500
# ...

# %%
for i in soup.find_all('span'):
  print(i.text.strip())
# Out:
# .in
# Delivering to Mumbai 400001
#
#
#                    Update location
# Delivering to Mumbai 400001
# Update location
# Books
#
# EN
#
# EN
#
#
# Hello, sign in
# Account & Lists
#
# Returns
# & Orders
#
#
#
#
# Cart
#
# All
# Fresh
#
# Prime
#
# Books
# Advanced Search
# New Releases & Pre-orders
# Best Sellers
#
# Browse Genres
#
# Children's & Young Adult
#
# Textbooks
#
# Exam Central
#
# All Indian Languages
#
# Amazon Bestsellers
# Our most popular products based on sales.  Updated frequently.
# #1
# I Don't Love You Anymore: Moving On and Living Your Best Life | National Bestseller by Rithvik Singh | Original Edition
# 4.1 out of 5 stars
# 367
# Paperback
# 17 offers from ₹215.00
# ₹215.00
# ₹215.00
# #2
# Amma Diarylo Konni Pageelu
# 4.8 out of 5 stars
# 520
# Paperback
# 4 offers from ₹200.00
# ₹200.00
# ₹200.00
# #3
# My First Library: Boxset of 10 Board Books for Kids
# 4.5 out of 5 stars
# 79,236
# Board book
# 14 offers from ₹399.00
# ₹399.00
# ₹399.00
# #4
# ...

# %%
for i in soup.find_all('a'):
  print(i.text.strip())
# Out:
# Skip to main content
# .in
# Delivering to Mumbai 400001
#
#
#                    Update location
# EN
# Hello, sign in
# Account & Lists
# Returns
# & Orders
# Cart
# All
# Fresh
# Amazon miniTV
# Sell
# Best Sellers
# Today's Deals
# Mobiles
# Customer Service
# Prime
# Electronics
# Fashion
# New Releases
# Home & Kitchen
# Amazon Pay
# Computers
# Gift Ideas
# Car & Motorbike
# Books
# Beauty & Personal Care
# Pet Supplies
# Home Improvement
# Grocery & Gourmet Foods
# Toys & Games
# Sports, Fitness & Outdoors
# Gift Cards
# Baby
# Custom Products
# Health, Household & Personal Care
# Video Games
# Audible
# AmazonBasics
# Subscribe & Save
# Coupons
#
# Books
# Advanced Search
# New Releases & Pre-orders
# Best Sellers
# Browse Genres
# Children's & Young Adult
# Textbooks
# Exam Central
# All Indian Languages
#
#
# I Don't Love You Anymore: Moving On and Living Your Best Life | National Bestseller by Rithvik Singh | Original Edition
# Rithvik Singh
# 4.1 out of 5 stars 367
# ...

# %%
for i in soup.find_all('img'):
  print(i.text.strip())

# %%
len(soup.find_all('div',class_='_cDEzb_iveVideoWrapper_JJ34T'))
# Out:
# 50

# %%
company=soup.find_all('div',class_='_cDEzb_iveVideoWrapper_JJ34T')
len(company)
# Out:
# 50

# %%
# df=pd.DataFrame(columns=['book_name','author_name','user_rating','book_link'])
book_name=[]
author_name=[]
user_rating=[]
book_link=[]
for i in company:

  book_name.append(i.find('div',class_='_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y').text.strip())
  author_name.append(i.find('p',class_='_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y').text.strip())
  user_rating.append(i.find('span' , class_='a-size-small').text.strip())
  book_link.append(i.find_all('p',class_='infoEntity')[0].text.strip())

df=pd.DataFrame({'bookname':book_name,
   'rating':author_name,
   'reviews':user_rating,
   'company_type':book_link,

   })
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-ebbdc72524e2> in <cell line: 6>()
#       7
#       8   book_name.append(i.find('div',class_='_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y').text.strip())
# ----> 9   author_name.append(i.find('p',class_='_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y').text.strip())
#      10   user_rating.append(i.find('span' , class_='a-size-small').text.strip())
#      11   book_link.append(i.find_all('p',class_='infoEntity')[0].text.strip())
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
len(soup.find_all('div',attrs={'class':"zg-grid-general-faceout"}))
# Out:
# 50

# %%
company=soup.find_all('div',attrs={'class':"zg-grid-general-faceout"})
company.text.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-31a3028f7267> in <cell line: 2>()
#       1 company=soup.find_all('div',attrs={'class':"zg-grid-general-faceout"})
# ----> 2 company.text.strip()
#
# /usr/local/lib/python3.10/dist-packages/bs4/element.py in __getattr__(self, key)
#    2431     def __getattr__(self, key):
#    2432         """Raise a helpful exception to explain a common code fix."""
# -> 2433         raise AttributeError(
#    2434             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
        book_name=d.find('div',attrs={'class':"_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y"})
        book_name
        # author_name=d.find('div',attrs={'class':"a-row a-size-small"})
        # user_rating=d.find('span',attrs={'class':"a-icon-alt"})
        # book_link=d.find('a',attrs={'class':"a-link-normal"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-b93e9b7188e1> in <cell line: 1>()
# ----> 1 book_name=d.find('div',attrs={'class':"_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y"})
#       2 book_name
#       3 # author_name=d.find('div',attrs={'class':"a-row a-size-small"})
#       4 # user_rating=d.find('span',attrs={'class':"a-icon-alt"})
#       5 # book_link=d.find('a',attrs={'class':"a-link-normal"})
#
# NameError: name 'd' is not defined

# %%
company=soup.find_all('div',attrs={'class':"zg-grid-general-faceout"})
company.text.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-31a3028f7267> in <cell line: 2>()
#       1 company=soup.find_all('div',attrs={'class':"zg-grid-general-faceout"})
# ----> 2 company.text.strip()
#
# /usr/local/lib/python3.10/dist-packages/bs4/element.py in __getattr__(self, key)
#    2431     def __getattr__(self, key):
#    2432         """Raise a helpful exception to explain a common code fix."""
# -> 2433         raise AttributeError(
#    2434             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
soup.find_all('div',attrs={'class':"zg-grid-general-faceout"}).text.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-874dbe0b9f5f> in <cell line: 1>()
# ----> 1 soup.find_all('div',attrs={'class':"zg-grid-general-faceout"}).text.strip()
#
# /usr/local/lib/python3.10/dist-packages/bs4/element.py in __getattr__(self, key)
#    2431     def __getattr__(self, key):
#    2432         """Raise a helpful exception to explain a common code fix."""
# -> 2433         raise AttributeError(
#    2434             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
soup.find_all('div',attrs={'class':"zg-grid-general-faceout"})[0].text.strip()
# Out:
# "I Don't Love You Anymore: Moving On and Living Your Best Life | National Bestseller by Rithvik Singh | Original EditionRithvik Singh4.1 out of 5 stars\u2009367Paperback17 offers from ₹215.00"

# %%
company=soup.find_all('div',attrs={'class':"zg-grid-general-faceout"}).text.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-be8279e14d4a> in <cell line: 1>()
# ----> 1 company=soup.find_all('div',attrs={'class':"zg-grid-general-faceout"}).text.strip()
#
# /usr/local/lib/python3.10/dist-packages/bs4/element.py in __getattr__(self, key)
#    2431     def __getattr__(self, key):
#    2432         """Raise a helpful exception to explain a common code fix."""
# -> 2433         raise AttributeError(
#    2434             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
company=soup.find_all('div',attrs={'class':"_cDEzb_iveVideoWrapper_JJ34T"})
company
# Out:
# [<div class="_cDEzb_iveVideoWrapper_JJ34T" data-asin="B0CY4WYQ8W"><div class="a-section zg-bdg-ctr"><div class="a-section zg-bdg-body zg-bdg-clr-body aok-float-left"><span class="zg-bdg-text">#1</span></div><div class="a-section zg-bdg-tri zg-bdg-clr-tri aok-float-left"></div></div><div class="zg-grid-general-faceout"><div class="p13n-sc-uncoverable-faceout" id="B0CY4WYQ8W"><a class="a-link-normal aok-block" href="/Dont-Love-You-Anymore-Bestseller/dp/B0CY4WYQ8W/ref=zg_bs_g_books_d_sccl_1/000-0000000-0000000?psc=1" role="link" tabindex="-1"><div class="a-section a-spacing-mini _cDEzb_noop_3Xbw5"><img alt="I Don't Love You Anymore: Moving On and Living Your Best Life | National Bestseller by Rithvik Singh | Original Edition" class="a-dynamic-image p13n-sc-dynamic-image p13n-product-image" data-a-dynamic-image='{"https://images-eu.ssl-images-amazon.com/images/I/61J5Z-OYUUL._AC_UL300_SR300,200_.jpg":[300,200],"https://images-eu.ssl-images-amazon.com/images/I/61J5Z-OYUUL._AC_UL600_SR600,4
# ...

# %%
for i in company:
  print(i)
# Out:
# <div class="_cDEzb_iveVideoWrapper_JJ34T" data-asin="B0CY4WYQ8W"><div class="a-section zg-bdg-ctr"><div class="a-section zg-bdg-body zg-bdg-clr-body aok-float-left"><span class="zg-bdg-text">#1</span></div><div class="a-section zg-bdg-tri zg-bdg-clr-tri aok-float-left"></div></div><div class="zg-grid-general-faceout"><div class="p13n-sc-uncoverable-faceout" id="B0CY4WYQ8W"><a class="a-link-normal aok-block" href="/Dont-Love-You-Anymore-Bestseller/dp/B0CY4WYQ8W/ref=zg_bs_g_books_d_sccl_1/000-0000000-0000000?psc=1" role="link" tabindex="-1"><div class="a-section a-spacing-mini _cDEzb_noop_3Xbw5"><img alt="I Don't Love You Anymore: Moving On and Living Your Best Life | National Bestseller by Rithvik Singh | Original Edition" class="a-dynamic-image p13n-sc-dynamic-image p13n-product-image" data-a-dynamic-image='{"https://images-eu.ssl-images-amazon.com/images/I/61J5Z-OYUUL._AC_UL300_SR300,200_.jpg":[300,200],"https://images-eu.ssl-images-amazon.com/images/I/61J5Z-OYUUL._AC_UL600_SR600,40
# ...

# %%
count=0
for i in company:
  count=count+1
  print(i)
# Out:
# <div class="zg-grid-general-faceout"><div class="p13n-sc-uncoverable-faceout" id="B0CY4WYQ8W"><a class="a-link-normal aok-block" href="/Dont-Love-You-Anymore-Bestseller/dp/B0CY4WYQ8W/ref=zg_bs_g_books_d_sccl_1/000-0000000-0000000?psc=1" role="link" tabindex="-1"><div class="a-section a-spacing-mini _cDEzb_noop_3Xbw5"><img alt="I Don't Love You Anymore: Moving On and Living Your Best Life | National Bestseller by Rithvik Singh | Original Edition" class="a-dynamic-image p13n-sc-dynamic-image p13n-product-image" data-a-dynamic-image='{"https://images-eu.ssl-images-amazon.com/images/I/61J5Z-OYUUL._AC_UL300_SR300,200_.jpg":[300,200],"https://images-eu.ssl-images-amazon.com/images/I/61J5Z-OYUUL._AC_UL600_SR600,400_.jpg":[600,400],"https://images-eu.ssl-images-amazon.com/images/I/61J5Z-OYUUL._AC_UL900_SR900,600_.jpg":[900,600]}' height="200px" src="https://images-eu.ssl-images-amazon.com/images/I/61J5Z-OYUUL._AC_UL300_SR300,200_.jpg" style="max-width:300px;max-height:200px"/></div></a><div>
# ...

# %%
count
# Out:
# 50

# %%
    author_name
    user_rating
    book_link
    for i in company:
        book_name=i.find('div',attrs={'class':"_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y"}).text.strip()
        author_name=i.find('div',attrs={'class':"a-row a-size-small"}).text.strip()
        user_rating=d.find('span',attrs={'class':"a-icon-alt"}).text.strip()
        book_link=d.find('a',attrs={'class':"a-link-normal"}).text.strip()
    book_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-4bb1b3b41581> in <cell line: 4>()
#       4 for i in company:
#       5     book_name=i.find('div',attrs={'class':"_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y"}).text.strip()
# ----> 6     author_name=d.find('div',attrs={'class':"a-row a-size-small"}).text.strip()
#       7     user_rating=d.find('span',attrs={'class':"a-icon-alt"}).text.strip()
#       8     book_link=d.find('a',attrs={'class':"a-link-normal"}).text.strip()
#
# NameError: name 'd' is not defined

# %%
from bs4 import BeautifulSoup
import requests

# Example URL (replace with actual URL)
url = 'https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_1_books?ie=UTF8&pg=1'
response = requests.get(url)

# Parse the content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Assuming 'company' is the list of all book items
company = soup.find_all('div', attrs={'class':"zg-grid-general-faceout"})  # Adjust the class name accordingly

# Lists to store extracted data
book_names = []
author_names = []
user_ratings = []
book_links = []

# Loop through each book item and extract details
for i in company:
    book_name = i.find('div', attrs={'class': "_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y"}).text.strip()
    author_name = i.find('div', attrs={'class': "a-row a-size-small"}).text.strip()
    user_rating = i.find('span', attrs={'class': "a-icon-alt"}).text.strip()
    book_link = i.find('a', attrs={'class': "a-link-normal"})['href'].strip()  # Use ['href'] to get the URL link

    # Append data to lists
    book_names.append(book_name)
    author_names.append(author_name)
    user_ratings.append(user_rating)
    book_links.append(book_link)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-05dfff2db06d> in <cell line: 21>()
#      22     book_name = i.find('div', attrs={'class': "_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y"}).text.strip()
#      23     author_name = i.find('div', attrs={'class': "a-row a-size-small"}).text.strip()
# ---> 24     user_rating = i.find('span', attrs={'class': "a-icon-alt"}).text.strip()
#      25     book_link = i.find('a', attrs={'class': "a-link-normal"})['href'].strip()  # Use ['href'] to get the URL link
#      26
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
len(company)
# Out:
# 50

# %%
print(company[0].text.strip())
# Out:
# I Don't Love You Anymore: Moving On and Living Your Best Life | National Bestseller by Rithvik Singh | Original EditionRithvik Singh4.1 out of 5 stars 367Paperback17 offers from ₹215.00

# %%
    book_name
    for i in company:

# %%
len(company)
# Out:
# 0

# %%
len(company)
# Out:
# 0

# %%
print(company[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-51-db8ae18d57ce> in <cell line: 1>()
# ----> 1 print(company[0])
#
# IndexError: list index out of range

# %%
len(company)
# Out:
# 0

# %%
print(company[0].text.strip())
# Out:
# I Don't Love You Anymore: Moving On and Living Your Best Life | National Bestseller by Rithvik Singh | Original EditionRithvik Singh4.1 out of 5 stars 367Paperback17 offers from ₹215.00

# %%
book_name = company[0].find('div', attrs={'class': '_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y'}).text.strip()
author_name = company[0].find('div', attrs={'class': 'a-row a-size-small'}).text.strip()
user_rating = company[0].find('span', attrs={'class': 'a-icon-alt'}).text.strip()
book_link = company[0].find('a', attrs={'class': 'a-link-normal'})['href'].strip()

print(f"Book Name: {book_name}")
print(f"Author Name: {author_name}")
print(f"User Rating: {user_rating}")
print(f"Book Link: {book_link}")
# Out:
# Book Name: I Don't Love You Anymore: Moving On and Living Your Best Life | National Bestseller by Rithvik Singh | Original Edition
# Author Name: Rithvik Singh
# User Rating: 4.1 out of 5 stars
# Book Link: /Dont-Love-You-Anymore-Bestseller/dp/B0CY4WYQ8W/ref=zg_bs_g_books_d_sccl_1/000-0000000-0000000?psc=1

# %%
from bs4 import BeautifulSoup
import requests

# Example URL (replace with actual URL)
url = 'https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_1_books?ie=UTF8&pg=1'
response = requests.get(url)

# Parse the content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Assuming 'company' is the list of all book items
company = soup.find_all('div', attrs={'class':"_cDEzb_iveVideoWrapper_JJ34T"})  # Adjust the class name accordingly

# Lists to store extracted data
book_names = []
author_names = []
user_ratings = []
book_links = []

# Loop through each book item and extract details
for i in company:
  #extracting the details from every element in company

    # Safely get book name
    book_name = i.find('div', attrs={'class': "_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y"})
    if book_name:
      book_name = book_name.text.strip()
    else:
     "No title"

    # Safely get author name
    author_name = i.find('div', attrs={'class': "a-row a-size-small"})
    if author_name:
     author_name = author_name.text.strip()
    else:
       "No author"

    # Safely get user rating
    rating_element = i.find('span', attrs={'class': "a-icon-alt"})
    if rating_element:
     user_rating = rating_element.text.strip()
    else:
       "No rating"

    # Safely get book link
    link_element = i.find('a', attrs={'class': "a-link-normal"})
    if link_element:
     book_link = link_element['href'].strip()
    else:
       "No link"

    # Append data to lists
    book_names.append(book_name)
    author_names.append(author_name)
    user_ratings.append(user_rating)
    book_links.append(book_link)



    # Append data to lists
    book_names.append(book_name)
    author_names.append(author_name)
    user_ratings.append(user_rating)
    book_links.append(book_link)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-f62e5c9a4795> in <cell line: 64>()
#      62 all1.append(user_ratings)
#      63 all1.append(book_link)
# ---> 64 al11
#
# NameError: name 'al11' is not defined

# %%
company[1].text.strip()
# Out:
# '#2Amma Diarylo Konni PageeluRavi Mantri4.8 out of 5 stars\u2009520Paperback4 offers from ₹200.00'

# %%
book_names
# Out:
# ["I Don't Love You Anymore: Moving On and Living Your Best Life | National Bestseller by Rithvik Singh | Original Edition",
#  'Amma Diarylo Konni Pageelu',
#  'My First Library: Boxset of 10 Board Books for Kids',
#  'Indian Economy 2 in 1 For Group 2 & 3 for TSPSC in Telugu By Chouti Sir',
#  'Atomic Habits',
#  'The Psychology of Money',
#  'The Power of Your Subconscious Mind: Original Edition | Premium Paperback',
#  'Ikigai: Japanese secret to long and happy life',
#  'My First Book of Patterns Pencil Control: Patterns Practice book for kids (Pattern Writing)',
#  'GANITPRAKASH, Textbook for Mathematics, Grade VI 674 Edition 2024',
#  'Shrimad Bhagwat Geeta Yatharoop (Hindi)',
#  "Don't Believe Everything You Think (English)",
#  'The Intelligent Investor (English) Paperback – 2013',
#  'Dopamine Detox : A Short Guide to Remove Distractions and Get Your Brain to Do Hard Things',
# ...

# %%
book_names
# Out:
# ["I Don't Love You Anymore: Moving On and Living Your Best Life | National Bestseller by Rithvik Singh | Original Edition",
#  'Amma Diarylo Konni Pageelu',
#  'My First Library: Boxset of 10 Board Books for Kids',
#  'Indian Economy 2 in 1 For Group 2 & 3 for TSPSC in Telugu By Chouti Sir',
#  'Atomic Habits',
#  'The Psychology of Money',
#  'The Power of Your Subconscious Mind: Original Edition | Premium Paperback',
#  'Ikigai: Japanese secret to long and happy life',
#  'My First Book of Patterns Pencil Control: Patterns Practice book for kids (Pattern Writing)',
#  'GANITPRAKASH, Textbook for Mathematics, Grade VI 674 Edition 2024',
#  'Shrimad Bhagwat Geeta Yatharoop (Hindi)',
#  "Don't Believe Everything You Think (English)",
#  'The Intelligent Investor (English) Paperback – 2013',
#  'Dopamine Detox : A Short Guide to Remove Distractions and Get Your Brain to Do Hard Things',
# ...

# %%
from bs4 import BeautifulSoup
import requests

# Example URL (replace with actual URL)
url = 'https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_1_books?ie=UTF8&pg=1'
response = requests.get(url)

# Parse the content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Assuming 'company' is the list of all book items
company = soup.find_all('div', attrs={'class':"_cDEzb_iveVideoWrapper_JJ34T"})  # Adjust the class name accordingly

# Lists to store extracted data
book_names = []
author_names = []
user_ratings = []
book_links = []

# Loop through each book item and extract details
for i in company:
  #extracting the details from every element in company

    # Safely get book name
    book_name = i.find('div', attrs={'class': "_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y"})
    if book_name:
      book_name = book_name.text.strip()
    else:
     "No title"

    # Safely get author name
    author_name = i.find('div', attrs={'class': "a-row a-size-small"})
    if author_name:
     author_name = author_name.text.strip()
    else:
       "No author"

    # Safely get user rating
    rating_element = i.find('span', attrs={'class': "a-icon-alt"})
    if rating_element:
     user_rating = rating_element.text.strip()
    else:
       "No rating"

    # Safely get book link
    link_element = i.find('a', attrs={'class': "a-link-normal"})
    if link_element:
     book_link = link_element['href'].strip()
    else:
       "No link"

    # Append data to lists
    book_names.append(book_name)
    author_names.append(author_name)
    user_ratings.append(user_rating)
    book_links.append('https://www.amazon.in'+book_link.get('href'))


all1=[]
all1.append(book_names)
all1.append(author_names)
all1.append(user_ratings)
all1.append(book_link)
all1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-00e99431c29e> in <cell line: 21>()
#      54     author_names.append(author_name)
#      55     user_ratings.append(user_rating)
# ---> 56     book_links.append('https://www.amazon.in'+book_link.get('href'))
#      57
#      58
#
# AttributeError: 'str' object has no attribute 'get'

# %%
df=pd.DataFrame({'name':book_names,
   'author':author_names,
   'ratings':user_ratings,
   'book_link':book_links,

   })

# %%
df
# Out:
#                                                  name  \
# 0   I Don't Love You Anymore: Moving On and Living...
# 1                          Amma Diarylo Konni Pageelu
# 2   My First Library: Boxset of 10 Board Books for...
# 3   Indian Economy 2 in 1 For Group 2 & 3 for TSPS...
# 4                             The Psychology of Money
# 5                                       Atomic Habits
# 6   GANITPRAKASH, Textbook for Mathematics, Grade ...
# 7   The Power of Your Subconscious Mind: Original ...
# 8      Ikigai: Japanese secret to long and happy life
# 9   My First Book of Patterns Pencil Control: Patt...
# 10            Shrimad Bhagwat Geeta Yatharoop (Hindi)
# 11       Don't Believe Everything You Think (English)
# 12  The Intelligent Investor (English) Paperback –...
# 13  All In One Social Science CBSE Class 10th Base...
# 14  Moral Story Books for Kids (Illustrated) - Eng...
# 15  Dopamine Detox : A Short Guide to Remove Distr...
# ...

# %%
from bs4 import BeautifulSoup
import requests

# Example URL
url = 'https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_1_books?ie=UTF8&pg=1'
response = requests.get(url)

# Parse the content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Assuming 'company' is the list of all book items
company = soup.find_all('div', attrs={'class': "_cDEzb_iveVideoWrapper_JJ34T"})  # Adjust the class name accordingly

# Lists to store extracted data
book_names = []
author_names = []
user_ratings = []
book_links = []

# Loop through each book item and extract details
for i in company:
    # Safely get book name
    book_name = i.find('div', attrs={'class': "_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y"})
    if book_name:
        book_name = book_name.text.strip()
    else:
        book_name = "No title"

    # Safely get author name
    author_name = i.find('div', attrs={'class': "a-row a-size-small"})
    if author_name:
        author_name = author_name.text.strip()
    else:
        author_name = "No author"

    # Safely get user rating
    rating_element = i.find('span', attrs={'class': "a-icon-alt"})
    if rating_element:
        user_rating = rating_element.text.strip()
    else:
        user_rating = "No rating"

    # Safely get book link
    link_element = i.find('a', attrs={'class': "a-link-normal"})
    if link_element:
        book_link = 'https://www.amazon.in' + link_element['href'].strip()
    else:
        book_link = "No link"

    # Append data to lists
    book_names.append(book_name)
    author_names.append(author_name)
    user_ratings.append(user_rating)
    book_links.append(book_link)

# Combine all lists into a single list
all1 = [book_names, author_names, user_ratings, book_links]

# Output the combined data for debugging
all1
# Out:
# [["I Don't Love You Anymore: Moving On and Living Your Best Life | National Bestseller by Rithvik Singh | Original Edition",
#   'Amma Diarylo Konni Pageelu',
#   'My First Library: Boxset of 10 Board Books for Kids',
#   'Indian Economy 2 in 1 For Group 2 & 3 for TSPSC in Telugu By Chouti Sir',
#   'The Psychology of Money',
#   'Atomic Habits',
#   'GANITPRAKASH, Textbook for Mathematics, Grade VI 674 Edition 2024',
#   'The Power of Your Subconscious Mind: Original Edition | Premium Paperback',
#   'Ikigai: Japanese secret to long and happy life',
#   'My First Book of Patterns Pencil Control: Patterns Practice book for kids (Pattern Writing)',
#   'Shrimad Bhagwat Geeta Yatharoop (Hindi)',
#   "Don't Believe Everything You Think (English)",
#   'The Intelligent Investor (English) Paperback – 2013',
# ...

# %%
df=pd.DataFrame({'name':book_names,
   'author':author_names,
   'ratings':user_ratings,
   'book_link':book_links,

   })

# %%
df
# Out:
#                                                  name  \
# 0   I Don't Love You Anymore: Moving On and Living...
# 1                          Amma Diarylo Konni Pageelu
# 2   My First Library: Boxset of 10 Board Books for...
# 3   Indian Economy 2 in 1 For Group 2 & 3 for TSPS...
# 4                             The Psychology of Money
# 5                                       Atomic Habits
# 6   GANITPRAKASH, Textbook for Mathematics, Grade ...
# 7   The Power of Your Subconscious Mind: Original ...
# 8      Ikigai: Japanese secret to long and happy life
# 9   My First Book of Patterns Pencil Control: Patt...
# 10            Shrimad Bhagwat Geeta Yatharoop (Hindi)
# 11       Don't Believe Everything You Think (English)
# 12  The Intelligent Investor (English) Paperback –...
# 13  All In One Social Science CBSE Class 10th Base...
# 14  Moral Story Books for Kids (Illustrated) - Eng...
# 15  Dopamine Detox : A Short Guide to Remove Distr...
# ...

# %%
from bs4 import BeautifulSoup
import requests

# Example URL
url = 'https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_1_books?ie=UTF8&pg=1'
response = requests.get(url)

# Parse the content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Assuming 'company' is the list of all book items
company = soup.find_all('div', attrs={'class': "_cDEzb_iveVideoWrapper_JJ34T"})  # Adjust the class name accordingly

# Lists to store extracted data
book_names = []
author_names = []
user_ratings = []
book_links = []

# Loop through each book item and extract details
for i in company:
    # Safely get book name
    book_name = i.find('div', attrs={'class': "_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y"})
    if book_name:
        book_name = book_name.text.strip()
    else:
        book_name = "No title"

    # Safely get author name
    author_name = i.find('div', attrs={'class': "a-row a-size-small"})
    if author_name:
        author_name = author_name.text.strip()
    else:
        author_name = "No author"

    # Safely get user rating
    rating_element = i.find('span', attrs={'class': "a-icon-alt"})
    if rating_element:
        user_rating = rating_element.text.strip()
    else:
        user_rating = "No rating"

    # Safely get book link
    link_element = i.find('a', attrs={'class': "a-link-normal"})
    if link_element:
        book_link = 'https://www.amazon.in' + link_element['href'].strip()
    else:
        book_link = "No link"

    # Append data to lists
    book_names.append(book_name)
    author_names.append(author_name)
    user_ratings.append(user_rating)
    book_links.append(book_link)

# Combine all lists into a single list
all1 = [book_names, author_names, user_ratings, book_links]

# Output the combined data for debugging
all1
